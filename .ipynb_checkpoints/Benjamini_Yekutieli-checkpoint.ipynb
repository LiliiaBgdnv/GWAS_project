# %%
import statsmodels.stats.multitest as stat
import pandas as pd
import matplotlib.pyplot as plt
from qmplot import manhattanplot
from typing import Tuple
from scipy import stats
import numpy as np

# %%
def manhattan_qq_plot(dataframe: pd.DataFrame, model: str, trait: str) -> Tuple[plt.Figure, plt.Axes]:
    """
    Generate a Manhattan plot and QQ plot based on the given dataframe, model, and trait.

    Args:
        dataframe (pd.DataFrame): Input dataframe containing the necessary data.
        model (str): Model type ('GLM' or other).
        trait (str): Trait type ('simple' or other).

    Returns:
        Tuple[plt.Figure, plt.Axes]: A tuple containing the generated figure and axes objects.
    """
    # Set suggestiveline based on trait type
    if trait == 'simple' or trait == 'simple generated':
        suggestiveline = 0.1
    else:
        suggestiveline = 0.05

    # Generate Manhattan plot
    if model == "GLM":
        # Generate Manhattan plot for GLM model
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), facecolor="w", edgecolor="k")
        ax1 = manhattanplot(data=dataframe,
                           suggestiveline=suggestiveline,
                           marker=".",
                           title=f"{model} {trait} trait",
                           sign_marker_color="r",
                           xlabel="Chr",
                           pv='P.value_BY',
                           is_annotate_topsnp=True,
                           text_kws={"fontsize": 12},
                           ax=ax1)
        # Calculate expected quantiles
        expected_quantiles = -np.log10(np.linspace(1 / len(dataframe['P']), 1, len(dataframe['P'])))

        # Calculate observed quantiles based on p-value
        observed_quantiles = -np.log10(np.sort(dataframe['P']))

    else:
        # Generate Manhattan plot for other models
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), facecolor="w", edgecolor="k")
        ax1 = manhattanplot(data=dataframe,
                           suggestiveline=suggestiveline,
                           marker=".",
                           chrom="Chr",
                           pos="Pos",
                           title=f"{model} {trait} trait",
                           sign_marker_color="r",
                           snp="SNP",
                           xlabel="Chr",
                           pv='P.value_BY',
                           is_annotate_topsnp=True,
                           text_kws={"fontsize": 12},
                           ax=ax1)
        # Calculate expected quantiles
        expected_quantiles = -np.log10(np.linspace(1 / len(dataframe['P.value']), 1, len(dataframe['P.value'])))

        # Calculate observed quantiles based on p-value
        observed_quantiles = -np.log10(np.sort(dataframe['P.value']))

    # Plot QQ plot on the second subplot
    ax2.scatter(expected_quantiles, observed_quantiles)
    ax2.plot([min(expected_quantiles), max(expected_quantiles)],
             [min(expected_quantiles), max(expected_quantiles)], color='red', linestyle='--')
    ax2.set_xlabel('Expected Quantiles')
    ax2.set_ylabel('Observed Quantiles')
    ax2.set_title(f'QQ Plot {model} {trait} trait')

    return fig, (ax1, ax2)

# %% [markdown]
# ## BLINK complex trait

# %%
df_soy_complex_b = pd.read_table('GAPIT/BLINK_complex/GAPIT.Association.GWAS_Results.BLINK.pheno.csv', sep=',')
df_soy_complex_b['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_b['P.value'], 
                                                                           alpha=0.05, 
                                                                           method='negcorr', 
                                                                           is_sorted=False)[1]
manhattan_qq_plot(df_soy_complex_b, 'BLINK', 'complex');

# %% [markdown]
# Let's see which SNPs have a P-value with Benjamini-Yetkutieli correction less than 0.05

# %%
df_soy_complex_b.loc[df_soy_complex_b['P.value_BY'] < 0.05]
# Out:
#          SNP Chr       Pos       P.value       MAF  nobs  H&B.P.Value  \
# 4413    4414   3  45355483  2.105178e-09  0.139175    97     0.000033
# 13038  13039   9  28490006  4.386478e-08  0.221649    97     0.000463
# 16482  16483  11  33243330  5.672423e-11  0.113402    97     0.000002
#
#            Effect  P.value_BY
# 4413   152.184998    0.000365
# 13038  105.772036    0.005067
# 16482 -148.898929    0.000020

# %% [markdown]
# ### BLINK complex trait generated data

# %%
df_soy_complex_b_gen = pd.read_table('GAPIT/BLINK_complex_gen/GAPIT.Association.GWAS_Results.BLINK.gen_pheno.csv', sep=',')
df_soy_complex_b_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_b_gen['P.value'], 
                                                                           alpha=0.05, 
                                                                           method='negcorr', 
                                                                           is_sorted=False)[1]
manhattan_qq_plot(df_soy_complex_b_gen, 'BLINK', 'complex generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# Great, no significant SNPs were found in the generated data

# %% [markdown]
# ## BLINK simple trait

# %%
df_soy_simple_b = pd.read_table('GAPIT/BLINK_simple/GAPIT.Association.GWAS_Results.BLINK.Leu.csv', sep=',')
df_soy_simple_b['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_b['P.value'], 
                                                                           alpha=0.05, 
                                                                           method='negcorr', 
                                                                           is_sorted=False)[1]
df_soy_simple_b['Chr'] = df_soy_simple_b['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_plot(df_soy_simple_b, 'BLINK', 'simple');

# %%
df_soy_simple_b.loc[df_soy_simple_b['P.value_BY'] < 0.1]
# Out:
#          SNP Chr       Pos   P.value       MAF  nobs  H&B.P.Value    Effect  \
# 20805  20806  18  61818402  0.000002  0.500000    97     0.006922  1.832510
# 20806  20807  18  61819070  0.000002  0.494845    97     0.006922 -1.843557
# 20809  20810  18  61846089  0.000002  0.494845    97     0.006922 -1.843557
# 20810  20811  18  61846097  0.000002  0.494845    97     0.006922 -1.843557
# 20812  20813  18  61846199  0.000002  0.494845    97     0.006922 -1.843557
# 20813  20814  18  61846240  0.000002  0.494845    97     0.006922  1.843557
# 20814  20815  18  61846255  0.000002  0.494845    97     0.006922  1.843557
# 20816  20817  18  61846357  0.000002  0.494845    97     0.006922  1.843557
#
#        P.value_BY
# 20805    0.073598
# 20806    0.073598
# 20809    0.073598
# 20810    0.073598
# 20812    0.073598
# 20813    0.073598
# 20814    0.073598
# 20816    0.073598

# %% [markdown]
# ### BLINK simple trait generated data

# %%
df_soy_simple_b_gen = pd.read_table('GAPIT/BLINK_simple_gen/GAPIT.Association.GWAS_Results.BLINK.Leu.csv', sep=',')
df_soy_simple_b_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_b_gen['P.value'], 
                                                                           alpha=0.05, 
                                                                           method='negcorr', 
                                                                           is_sorted=False)[1]
df_soy_simple_b_gen['Chr'] = df_soy_simple_b_gen['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_qq_plot(df_soy_simple_b_gen, 'BLINK', 'simple generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# ## FarmCPU complex trait

# %%
df_soy_complex_f = pd.read_table('GAPIT/FarmCPU_complex/GAPIT.Association.GWAS_Results.FarmCPU.pheno.csv', sep=',')
df_soy_complex_f['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_f['P.value'], 
                                                    alpha=0.05, 
                                                    method='negcorr', 
                                                    is_sorted=False)[1]
manhattan_qq_plot(df_soy_complex_f, 'FarmCPU', 'complex');

# %%
df_soy_complex_f.loc[df_soy_complex_f['P.value_BY'] < 0.05]
# Out:
#          SNP Chr       Pos       P.value       MAF  nobs  H&B.P.Value  \
# 4413    4414   3  45355483  2.582480e-08  0.139175    97     0.000409
# 16482  16483  11  33243330  3.213935e-10  0.113402    97     0.000010
# 17485  17486  12  39996708  4.037204e-08  0.164948    97     0.000426
# 18908  18909  13  39682867  2.308432e-07  0.139175    97     0.001462
# 30543  30544  20  36271980  1.509955e-07  0.474227    97     0.001196
#
#            Effect  P.value_BY
# 4413   103.164183    0.004475
# 16482 -106.232198    0.000111
# 17485  -72.724239    0.004664
# 18908  -72.267450    0.016000
# 30543   37.666141    0.013082

# %% [markdown]
# ### FarmCPU complex trait generated data

# %%
df_soy_complex_f_gen = pd.read_table('GAPIT/FarmCPU_complex_gen/GAPIT.Association.GWAS_Results.FarmCPU.gen_pheno.csv', sep=',')
df_soy_complex_f_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_f_gen['P.value'], 
                                                    alpha=0.05, 
                                                    method='negcorr', 
                                                    is_sorted=False)[1]
manhattan_qq_plot(df_soy_simple_f_gen, 'FarmCPU', 'complex generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# ## FarmCPU simple trait

# %%
df_soy_simple_f = pd.read_table('GAPIT/FarmCPU_simple/GAPIT.Association.GWAS_Results.FarmCPU.Leu.csv', sep=',')
df_soy_simple_f['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_f['P.value'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]
df_soy_simple_f['Chr'] = df_soy_simple_f['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_qq_plot(df_soy_simple_f, 'FarmCPU', 'simple');

# %%
df_soy_simple_f.loc[df_soy_simple_f['P.value_BY'] < 0.1]
# Out:
#          SNP Chr       Pos   P.value       MAF  nobs  H&B.P.Value    Effect  \
# 20805  20806  18  61818402  0.000002  0.500000    97     0.006939  1.832510
# 20806  20807  18  61819070  0.000002  0.494845    97     0.006939 -1.843557
# 20809  20810  18  61846089  0.000002  0.494845    97     0.006939 -1.843557
# 20810  20811  18  61846097  0.000002  0.494845    97     0.006939 -1.843557
# 20812  20813  18  61846199  0.000002  0.494845    97     0.006939 -1.843557
# 20813  20814  18  61846240  0.000002  0.494845    97     0.006939  1.843557
# 20814  20815  18  61846255  0.000002  0.494845    97     0.006939  1.843557
# 20816  20817  18  61846357  0.000002  0.494845    97     0.006939  1.843557
#
#        P.value_BY
# 20805     0.07378
# 20806     0.07378
# 20809     0.07378
# 20810     0.07378
# 20812     0.07378
# 20813     0.07378
# 20814     0.07378
# 20816     0.07378

# %% [markdown]
# ### FarmCPU simple trait generated data

# %%
df_soy_simple_f_gen = pd.read_table('GAPIT/FarmCPU_simple_gen/GAPIT.Association.GWAS_Results.FarmCPU.Leu.csv', sep=',')
df_soy_simple_f_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_f_gen['P.value'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]
df_soy_simple_f_gen['Chr'] = df_soy_simple_f_gen['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_qq_plot(df_soy_simple_f_gen, 'FarmCPU', 'simple generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# ## SUPER complex trait

# %%
df_soy_complex_s = pd.read_table('GAPIT/SUPER_complex/GAPIT.Association.GWAS_Results.SUPER.pheno.csv', sep=',')
df_soy_complex_s['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_s['P.value'], 
                                                    alpha=0.05, 
                                                    method='negcorr', 
                                                    is_sorted=False)[1]
manhattan_qq_plot(df_soy_complex_s, 'SUPER', 'complex');

# %%
df_soy_complex_s.loc[df_soy_complex_s['P.value_BY'] < 0.05]
# Out:
#          SNP Chr       Pos       P.value       MAF  nobs  H&B.P.Value  Effect  \
# 3025    3026   3   4891054  4.335992e-07  0.097938    92     0.000901     NaN
# 3026    3027   3   4891056  4.335992e-07  0.097938    92     0.000901     NaN
# 4413    4414   3  45355483  5.117551e-07  0.139175    92     0.000901     NaN
# 6778    6779   5   4355701  4.487133e-08  0.128866    92     0.000448     NaN
# 6802    6803   5   4684569  2.140147e-07  0.154639    92     0.000678     NaN
# 7397    7398   5  35824337  5.068382e-07  0.108247    92     0.000901     NaN
# 10193  10194   7  17555663  8.851254e-07  0.180412    92     0.001274     NaN
# 10194  10195   7  17555788  8.851254e-07  0.180412    92     0.001274     NaN
# 10208  10209   7  17902694  1.131762e-07  0.108247    92     0.000448     NaN
# 10209  10210   7  17902749  1.131762e-07  0.108247    92     0.000448     NaN
# 10210  10211   7  17902783  1.131762e-07  0.108247    92     0.000448     NaN
# 10303  10304   7  23283363  5.040560e-07  0.170103    92     0.000901     NaN
# 10395  10396   7  27170909  5.601007e-07  0.123711    92     0.000934     NaN
# 13889  13890   9  49775192  2.710947e-06  0.123711    92     0.003435     NaN
# 13927  13928  10    571336  1.519808e-06  0.118557    92     0.002006     NaN
# 15393  15394  10  40256295  3.006699e-07  0.097938    92     0.000866     NaN
# 15395  15396  10  40282492  1.041465e-07  0.082474    92     0.000448     NaN
# 15402  15403  10  40347104  7.612461e-08  0.077320    92     0.000448     NaN
# 15403  15404  10  40378675  1.126919e-07  0.072165    92     0.000448     NaN
# 15409  15410  10  40511307  4.114170e-07  0.139175    92     0.000901     NaN
# 16482  16483  11  33243330  2.187112e-08  0.113402    92     0.000448     NaN
# 26074  26075  18   3591942  8.484215e-07  0.154639    92     0.001274     NaN
# 29212  29213  19  37737773  3.646083e-06  0.118557    92     0.004442     NaN
# 29323  29324  19  39915150  1.092608e-06  0.123711    92     0.001505     NaN
# 29652  29653  19  47795676  2.096792e-07  0.103093    92     0.000678     NaN
# 29653  29654  19  47796136  3.403196e-07  0.108247    92     0.000898     NaN
#
#        P.value_BY
# 3025     0.009853
# 3026     0.009853
# 4413     0.009853
# 6778     0.004903
# 6802     0.007417
# 7397     0.009853
# 10193    0.013943
# 10194    0.013943
# 10208    0.004903
# 10209    0.004903
# 10210    0.004903
# 10303    0.009853
# 10395    0.010216
# 13889    0.037579
# 13927    0.021946
# 15393    0.009473
# 15395    0.004903
# 15402    0.004903
# 15403    0.004903
# 15409    0.009853
# 16482    0.004903
# 26074    0.013943
# 29212    0.048598
# 29323    0.016463
# 29652    0.007417
# 29653    0.009828

# %% [markdown]
# ### SUPER complex trait generated data

# %%
df_soy_complex_s_gen = pd.read_table('GAPIT/SUPER_complex_gen/GAPIT.Association.GWAS_Results.SUPER.gen_pheno.csv', sep=',')
df_soy_complex_s_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_s_gen['P.value'], 
                                                    alpha=0.05, 
                                                    method='negcorr', 
                                                    is_sorted=False)[1]
manhattan_qq_plot(df_soy_complex_s_gen, 'SUPER', 'complex generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# ## SUPER simple trait

# %%
df_soy_simple_s = pd.read_table('GAPIT/SUPER_simple/GAPIT.Association.GWAS_Results.SUPER.Leu.csv', sep=',')
df_soy_simple_s['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_s['P.value'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]
df_soy_simple_s['Chr'] = df_soy_simple_s['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_qq_plot(df_soy_simple_s, 'SUPER', 'simple');

# %%
df_soy_simple_s.loc[df_soy_simple_s['P.value_BY'] < 0.1]
# Out:
# Empty DataFrame
# Columns: [SNP, Chr, Pos, P.value, MAF, nobs, H&B.P.Value, Effect, P.value_BY]
# Index: []

# %% [markdown]
# ### SUPER simple trait generated data

# %%
df_soy_simple_s_gen = pd.read_table('GAPIT/SUPER_simple_gen/GAPIT.Association.GWAS_Results.SUPER.Leu.csv', sep=',')
df_soy_simple_s_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_s_gen['P.value'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]
df_soy_simple_s_gen['Chr'] =  df_soy_simple_s_gen['Chr'].str.replace('[^0-9]', '', regex=True)
manhattan_qq_plot(df_soy_simple_s_gen, 'SUPER', 'simple generated');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))

# %% [markdown]
# ## GLM simple trait

# %%
df_soy_simple_g = pd.read_table('plink_glm/results/simple_glm_result_chr.Leu.glm.linear', sep="\t")
df_soy_simple_g['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_g['P'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]
manhattan_qq_plot(df_soy_simple_g, 'GLM', 'simple');

# %%
df_soy_simple_g.loc[df_soy_simple_g['P.value_BY'] < 0.1]
# Out:
#       #CHROM       POS ID REF ALT A1 TEST  OBS_CT      BETA        SE  \
# 1254       1  55451641  .   G   A  A  ADD     238  0.910288  0.217920
# 1256       1  55573886  .   C   T  T  ADD     238  0.920631  0.213698
# 1262       1  55605372  .   T   C  C  ADD     238  0.973711  0.207770
# 1263       1  55605442  .   C   T  T  ADD     238  0.926701  0.208427
# 3228       3  37364557  .   T   C  C  ADD     235  0.930210  0.215269
# ...      ...       ... ..  ..  .. ..  ...     ...       ...       ...
# 22719     20  34369312  .   T   C  C  ADD     238  0.997010  0.222392
# 22720     20  34381866  .   A   C  C  ADD     236  1.390240  0.317850
# 22721     20  34381881  .   T   C  C  ADD     236  1.399090  0.312719
# 23066     20  42531505  .   C   G  G  ADD     237 -1.770010  0.354099
# 23069     20  42569717  .   C   T  T  ADD     237 -1.394480  0.322252
#
#         T_STAT         P ERRCODE  P.value_BY
# 1254   4.17717  0.000042       .    0.092444
# 1256   4.30810  0.000024       .    0.076182
# 1262   4.68649  0.000005       .    0.058373
# 1263   4.44616  0.000013       .    0.061698
# 3228   4.32115  0.000023       .    0.076182
# ...        ...       ...     ...         ...
# 22719  4.48312  0.000011       .    0.058373
# 22720  4.37388  0.000018       .    0.073059
# 22721  4.47397  0.000012       .    0.058373
# 23066 -4.99863  0.000001       .    0.058373
# 23069 -4.32729  0.000022       .    0.076182
#
# [114 rows x 14 columns]

# %% [markdown]
# ### GLM simple trait generated data

# %%
df_soy_simple_g_gen = pd.read_table('plink_glm/results/simple_glm_gen_result_chr.Leu.glm.linear', sep="\t")
df_soy_simple_g_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_simple_g_gen['P'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]

manhattan_qq_plot(df_soy_simple_g, 'GLM', 'simple generated');

# %% [markdown]
# ## GLM complex trait

# %%
df_soy_complex_g = pd.read_table('plink_glm/results/complex_glm_result.PHENO1.glm.linear', sep="\t")
df_soy_complex_g = df_soy_complex_g.dropna(how="any", axis=0)
df_soy_complex_g['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_g['P'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]

manhattan_qq_plot(df_soy_complex_g, 'GLM', 'complex');

# %%
df_soy_complex_g.loc[df_soy_complex_g['P.value_BY'] < 0.05]
# Out:
#       #CHROM       POS              ID REF ALT A1 TEST  OBS_CT     BETA  \
# 1324       2   2413639   2_2413639_T_A   T   A  T  ADD      69  231.835
# 6379       4  49624157  4_49624157_G_A   G   A  G  ADD      94  133.695
# 6380       4  49624172  4_49624172_T_C   T   C  T  ADD      94  125.148
# 6741       5   4684401   5_4684401_T_A   T   A  A  ADD      79  207.391
# 6742       5   4684477   5_4684477_A_T   A   T  T  ADD      79  207.391
# 6744       5   4684643   5_4684643_T_A   T   A  A  ADD      84  164.749
# 10099      7  17511124  7_17511124_G_C   G   C  C  ADD      96  150.987
# 10100      7  17518806  7_17518806_T_C   T   C  C  ADD      87  159.815
# 10117      7  17902694  7_17902694_G_A   G   A  A  ADD      92  171.604
# 10118      7  17902749  7_17902749_T_G   T   G  G  ADD      92  171.604
# 10119      7  17902783  7_17902783_A_G   A   G  G  ADD      92  171.604
# 10129      7  18593304  7_18593304_G_A   G   A  A  ADD      88  198.691
#
#             SE   T_STAT             P ERRCODE  P.value_BY
# 1324   36.3810  6.37242  1.976120e-08       .    0.002255
# 6379   24.0820  5.55167  2.715930e-07       .    0.013282
# 6380   24.1933  5.17286  1.341110e-06       .    0.038258
# 6741   39.3825  5.26608  1.226310e-06       .    0.038258
# 6742   39.3825  5.26608  1.226310e-06       .    0.038258
# 6744   31.4701  5.23511  1.246270e-06       .    0.038258
# 10099  24.4453  6.17652  1.661220e-08       .    0.002255
# 10100  29.5888  5.40119  5.924080e-07       .    0.025350
# 10117  28.6512  5.98943  4.255580e-08       .    0.002428
# 10118  28.6512  5.98943  4.255580e-08       .    0.002428
# 10119  28.6512  5.98943  4.255580e-08       .    0.002428
# 10129  31.6936  6.26911  1.400450e-08       .    0.002255

# %% [markdown]
# ### GLM complex trait generated data

# %%
df_soy_complex_g_gen = pd.read_table('plink_glm/results/complex_glm_gen_plink_result.PHENO1.glm.linear', sep="\t")
df_soy_complex_g_gen = df_soy_complex_g_gen.dropna(how="any", axis=0)
df_soy_complex_g_gen['P.value_BY'] = stat.fdrcorrection(pvals=df_soy_complex_g_gen['P'], 
                                                   alpha=0.05, 
                                                   method='negcorr', 
                                                   is_sorted=False)[1]

manhattan_qq_plot(df_soy_complex_g_gen, 'GLM', 'complex genetared');
# Out:
# /Users/iskys/venv/lib/python3.9/site-packages/qmplot/modules/_manhattan.py:346: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(ymin=min(y), ymax=1.2 * max(y))
